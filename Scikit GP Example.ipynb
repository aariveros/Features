# %% [raw]
# Este script es un ejemplo simple de ajustar un gp con scikit a una curva de luz

# %%
import lightcurves.lc_utils as lu
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
def graf(include_error_bars=False):
    # Make the prediction on the meshed x-axis (ask for MSE as well)
    num_locs = 600
    extra_time = 0.0
    
    x = np.asmatrix(np.linspace(min_time,max_time + extra_time,num_locs)).T
    y_pred, MSE = gp.predict(x, eval_MSE=True)
    sigma = np.sqrt(MSE)
    
    # Plot the function, the prediction and the 95% confidence interval based on the MSE
    fig = plt.figure()
    
    # Grafico las observaciones
    X2 = np.array(X)
    X2 = (X2.T).ravel()
    plt.plot(X2,y,'.r')
    
    if include_error_bars:
        plt.errorbar(X2.ravel(), y, dy, fmt='r.', markersize=10)
    
    # Grafico la regresión ajustada
    X3 = np.array(x)
    X3 = X3.ravel()
    plt.plot(X3, y_pred, 'b-', label=u'Prediction')
    
    # Agrego el intervalo de confianza
    plt.fill(np.concatenate([X3, X3[::-1]]), \
            np.concatenate([y_pred - 1.9600 * sigma,
                           (y_pred + 1.9600 * sigma)[::-1]]), \
            alpha=.5, fc='b', ec='None', label='95% confidence interval')
    
    # Leyenda
    plt.xlabel('$x$')
    plt.ylabel('$f(x)$')
    plt.legend(loc='upper right')

# %% [markdown]
# Primero abro una curva de ejemplo y la grafico

# %%
# Ubicacion de las curvas
# 0-1           Be_lc
# 255-256       CEPH
# 457-458       EB
# 967-968       longperiod_lc
# 1697-1698     microlensing_lc
# 2862-2863     non_variables
# 12527-12528   quasar_lc
# 12645-12646   RRL

paths = lu.get_lightcurve_paths()
a, b = 967, 968

azul = lu.open_lightcurve(paths[a])
roja = lu.open_lightcurve(paths[b])
curva = pd.concat([azul, roja], axis=1, keys=['azul', 'roja'], join='inner')

plt.plot( curva.index, curva['azul']['mag'], '.', color = 'b')

# %% [markdown]
# Calculo feature Eta con distintos porcentajes de la curva

# %%
import lightcurves.features as ft

n = len(curva.index)

print ft.eta(curva)
print ft.eta(curva.iloc[0:int(n * 0.8)])
print ft.eta(curva.iloc[0:int(n * 0.6)])
print ft.eta(curva.iloc[0:int(n * 0.4)])
print ft.eta(curva.iloc[0:int(n * 0.2)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-3e558c655714> in <module>()
#       3 n = len(curva.index)
#       4
# ----> 5 print ft.eta(curva)
#       6 print ft.eta(curva.iloc[0:int(n * 0.8)])
#       7 print ft.eta(curva.iloc[0:int(n * 0.6)])
#
# /Users/npcastro/workspace/Features/lightcurves/features.pyc in eta(X)
#      27
#      28     for i in xrange(n - 1):
# ---> 29         aux = X[i+1] - X[i]
#      30         nSum += aux**2
#      31
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1680             return self._getitem_frame(key)
#    1681         elif is_mi_columns:
# -> 1682             return self._getitem_multilevel(key)
#    1683         else:
#    1684             return self._getitem_column(key)
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_multilevel(self, key)
#    1724
#    1725     def _getitem_multilevel(self, key):
# -> 1726         loc = self.columns.get_loc(key)
#    1727         if isinstance(loc, (slice, Series, np.ndarray)):
#    1728             new_columns = self.columns[loc]
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    3364                 return result
#    3365         else:
# -> 3366             return self._get_level_indexer(key, level=0)
#    3367
#    3368     def get_loc_level(self, key, level=0, drop_level=True):
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in _get_level_indexer(self, key, level)
#    3529         else:
#    3530
# -> 3531             loc = level_index.get_loc(key)
#    3532             if level > 0 or self.lexsort_depth == 0:
#    3533                 return np.array(labels == loc,dtype=bool)
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3650)()
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3528)()
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11908)()
#
# /Users/npcastro/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11861)()
#
# KeyError: 1

# %% [markdown]
# Preparo los datos de la curva azul

# %%
import numpy as np
import random

# Array con los tiempos de medicion normalizados
t_obs = np.array(azul.index.reshape(len(azul.index),1))
t_obs = (t_obs - np.mean(t_obs)) / np.std(t_obs)

# Array con los brillos normalizados
y_obs = azul['mag'].reshape(len(azul.index), 1)
y_obs = (y_obs - np.mean(y_obs)) / np.std(y_obs)

# Array con los errores de las mediciones normalizados segun las observaciones
# No tiene sentido centrar los errores
err_obs = azul['err'].reshape(len(azul.index), 1)
err_obs = err_obs / azul['mag'].std()

min_time = np.min(t_obs)
max_time = np.max(t_obs)

# Tomo una muestra aleatoria de puntos de la curva
random.seed(1)
degree = 100
rand_indices = random.sample(range(0,np.max(np.shape(t_obs))),degree)
rand_indices.sort()

t_obs = t_obs[rand_indices]
y_obs = y_obs[rand_indices]
err_obs = err_obs[rand_indices]

# Transformo a matriz
t_obs = np.asmatrix(t_obs)
y_obs = np.asmatrix(y_obs)
err_obs = np.asmatrix(err_obs)

# %% [markdown]
# ### Gaussian Process

# %% [markdown]
# Datos sin ruido. Ajuste con estimacion MLE del parámetro de regularización

# %%
import numpy as np
from sklearn.gaussian_process import GaussianProcess
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
#  Noiseless case

X = t_obs
y = np.array(y_obs.T)[0]

gp = GaussianProcess(corr='squared_exponential', theta0=1e-1, regr='quadratic',
                     thetaL=1e-15, thetaU=1,
                     random_start=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Parámetro de parametrización óptimo
print gp.theta_
# Out:
# [[ 0.0019188]]

# %%
graf()

# %% [markdown]
# Datos considerando el error de las mediciones del dataset

# %%
import numpy as np
from sklearn.gaussian_process import GaussianProcess
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# Pruebo tomando como error el que viene con las mediciones
dy = np.sqrt(np.array(err_obs.T)[0])
#dy = np.array(err_obs.T)[0]

X = t_obs
y = np.array(y_obs.T)[0]

# Mesh the input space for evaluations of the real function, the prediction and its MSE
# Instanciate a Gaussian Process model
gp = GaussianProcess(corr='squared_exponential', theta0=1e-1,
                     thetaL=1e-15, thetaU=1,
                     nugget=(dy/y)**2,
                     random_start=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp = gp.fit(X, y)

# Parámetro de parametrización óptimo
print gp.theta_
# Out:
# [[ 0.0036886]]

# %%
graf()

# %%
import numpy as np
from sklearn.gaussian_process import GaussianProcess
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# Artificial noisy case
X = t_obs
y = np.array(y_obs.T)[0]

np.random.seed(1)
dy = 0.25 + 1.0 * np.random.random(y.shape)
noise = np.random.normal(0, dy)
y += noise


# Mesh the input space for evaluations of the real function, the prediction and its MSE
# Instanciate a Gaussian Process model
gp = GaussianProcess(corr='squared_exponential', theta0=1e-1,
                     thetaL=1e-3, thetaU=1,
                     nugget=(dy/y)**2,
                     random_start=100)


# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Parámetro de parametrización óptimo
print gp.theta_
# Out:
# [[ 1.]]

# %%
graf(include_error_bars=True)
